# %%
import joblib
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
pip install pandas numpy matplotlib seaborn scikit-learn
# Out:
# Requirement already satisfied: pandas in c:\users\venkatarao\anaconda3\lib\site-packages (2.1.4)
# Requirement already satisfied: numpy in c:\users\venkatarao\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\venkatarao\anaconda3\lib\site-packages (3.8.0)
# Requirement already satisfied: seaborn in c:\users\venkatarao\anaconda3\lib\site-packages (0.12.2)
# Requirement already satisfied: scikit-learn in c:\users\venkatarao\anaconda3\lib\site-packages (1.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\venkatarao\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\venkatarao\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\venkatarao\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\venkatarao\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\venkatarao\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\venkatarao\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\venkatarao\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\venkatarao\anaconda3\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\venkatarao\anaconda3\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\venkatarao\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\venkatarao\anaconda3\lib\site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\venkatarao\anaconda3\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\venkatarao\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\venkatarao\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import joblib
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
# Load data
df = pd.read_csv("3ae033f50fa345051652.csv")

# %%
df.head()
# Out:
#                 Date          County State Vehicle Primary Use  \
# 0  September 30 2022       Riverside    CA           Passenger
# 1   December 31 2022  Prince William    VA           Passenger
# 2    January 31 2020          Dakota    MN           Passenger
# 3       June 30 2022           Ferry    WA               Truck
# 4       July 31 2021         Douglas    CO           Passenger
#
#   Battery Electric Vehicles (BEVs) Plug-In Hybrid Electric Vehicles (PHEVs)  \
# 0                                7                                        0
# 1                                1                                        2
# 2                                0                                        1
# 3                                0                                        0
# 4                                0                                        1
#
#   Electric Vehicle (EV) Total Non-Electric Vehicle Total Total Vehicles  \
# 0                           7                        460            467
# 1                           3                        188            191
# 2                           1                         32             33
# 3                           0                      3,575          3,575
# 4                           1                         83             84
#
#    Percent Electric Vehicles
# 0                       1.50
# 1                       1.57
# 2                       3.03
# 3                       0.00
# 4                       1.19

# %%
# Converts the "Date" column to actual datetime objects
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

# Removes rows where "Date" conversion failed
df = df[df['Date'].notnull()]

# Removes rows where the target (EV Total) is missing
df = df[df['Electric Vehicle (EV) Total'].notnull()]

# Fill missing values
df['County'] = df['County'].fillna('Unknown')
df['State'] = df['State'].fillna('Unknown')

# Confirm remaining nulls
print("Missing after fill:")
print(df[['County', 'State']].isnull().sum())

df.head()
# Out:
# Missing after fill:
# County    0
# State     0
# dtype: int64
#         Date          County State Vehicle Primary Use  \
# 0 2022-09-30       Riverside    CA           Passenger
# 1 2022-12-31  Prince William    VA           Passenger
# 2 2020-01-31          Dakota    MN           Passenger
# 3 2022-06-30           Ferry    WA               Truck
# 4 2021-07-31         Douglas    CO           Passenger
#
#   Battery Electric Vehicles (BEVs) Plug-In Hybrid Electric Vehicles (PHEVs)  \
# 0                                7                                        0
# 1                                1                                        2
# 2                                0                                        1
# 3                                0                                        0
# 4                                0                                        1
#
#   Electric Vehicle (EV) Total Non-Electric Vehicle Total Total Vehicles  \
# 0                           7                        460            467
# 1                           3                        188            191
# 2                           1                         32             33
# 3                           0                      3,575          3,575
# 4                           1                         83             84
#
#    Percent Electric Vehicles
# 0                       1.50
# 1                       1.57
# 2                       3.03
# 3                       0.00
# 4                       1.19

# %%
# Cap the outliers - it keeps all the data while reducing the skew from extreme values.

df['Percent Electric Vehicles'] = np.where(df['Percent Electric Vehicles'] > upper_bound, upper_bound,
                                 np.where(df['Percent Electric Vehicles'] < lower_bound, lower_bound, df['Percent Electric Vehicles']))

# Identify outliers
outliers = df[(df['Percent Electric Vehicles'] < lower_bound) | (df['Percent Electric Vehicles'] > upper_bound)]
print("Number of outliers in 'Percent Electric Vehicles':", outliers.shape[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 # Cap the outliers - it keeps all the data while reducing the skew from extreme values.
# ----> 3 df['Percent Electric Vehicles'] = np.where(df['Percent Electric Vehicles'] > upper_bound, upper_bound,
#       4                                  np.where(df['Percent Electric Vehicles'] < lower_bound, lower_bound, df['Percent Electric Vehicles']))
#       6 # Identify outliers
#       7 outliers = df[(df['Percent Electric Vehicles'] < lower_bound) | (df['Percent Electric Vehicles'] > upper_bound)]
#
# NameError: name 'upper_bound' is not defined

# %%
# Identify outliers first (before modifying the values)
outliers = df[(df['Percent Electric Vehicles'] < lower_bound) | 
              (df['Percent Electric Vehicles'] > upper_bound)]

print("Number of outliers in 'Percent Electric Vehicles':", outliers.shape[0])

# Then cap the outliers
df['Percent Electric Vehicles'] = np.where(
    df['Percent Electric Vehicles'] > upper_bound, upper_bound,
    np.where(df['Percent Electric Vehicles'] < lower_bound, lower_bound, df['Percent Electric Vehicles'])
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Identify outliers first (before modifying the values)
# ----> 2 outliers = df[(df['Percent Electric Vehicles'] < lower_bound) |
#       3               (df['Percent Electric Vehicles'] > upper_bound)]
#       5 print("Number of outliers in 'Percent Electric Vehicles':", outliers.shape[0])
#       7 # Then cap the outliers
#
# NameError: name 'lower_bound' is not defined
